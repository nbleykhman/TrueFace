# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load pretrain data
pretrain_data = pd.DataFrame({
    'epoch': list(range(1, 37)),
    'train_loss': [0.7100, 0.6346, 0.5580, 0.4781, 0.3990, 0.6119, 0.5548, 0.5320, 0.5150, 0.5003,
                   0.4866, 0.4762, 0.4666, 0.4576, 0.4499, 0.4433, 0.4387, 0.4320, 0.4270, 0.4216,
                   0.4182, 0.4146, 0.4110, 0.4076, 0.4038, 0.4018, 0.3986, 0.3986, 0.3946, 0.3924,
                   0.3910, 0.3892, 0.3858, 0.3872, 0.3862, 0.3865],
    'val_loss': [0.6908, 0.6819, 0.6739, 0.6769, 0.6944, 0.7284, 0.7189, 0.7140, 0.7082, 0.7005,
                 0.6959, 0.6860, 0.6845, 0.6650, 0.6535, 0.6435, 0.6234, 0.6180, 0.6124, 0.5844,
                 0.5642, 0.5477, 0.5305, 0.5094, 0.4964, 0.4722, 0.4627, 0.4525, 0.4398, 0.4246,
                 0.4113, 0.4040, 0.3938, 0.3863, 0.3802, 0.3753],
    'val_auc': [0.5801, 0.6002, 0.6286, 0.6582, 0.6868, 0.6853, 0.7116, 0.7365, 0.7577, 0.7796,
                0.7992, 0.8148, 0.8279, 0.8448, 0.8558, 0.8672, 0.8746, 0.8863, 0.8919, 0.8992,
                0.9060, 0.9150, 0.9187, 0.9235, 0.9292, 0.9340, 0.9369, 0.9410, 0.9448, 0.9497,
                0.9532, 0.9559, 0.9585, 0.9611, 0.9636, 0.9653]
})

# %%
# Load finetune data
finetune_data = pd.DataFrame({
    'epoch': list(range(1, 6)),
    'train_loss': [0.6410, 0.5635, 0.5025, 0.4592, 0.4296],
    'val_loss': [0.6868, 0.7193, 0.5283, 0.3838, 0.4508],
    'val_auc': [0.7155, 0.8148, 0.9442, 0.9871, 0.9963]
})

# %%
# Plot Pretraining Loss and AUC
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(pretrain_data['epoch'], pretrain_data['train_loss'], label='Train Loss')
plt.plot(pretrain_data['epoch'], pretrain_data['val_loss'], label='Validation Loss')
plt.title('Pretraining Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(pretrain_data['epoch'], pretrain_data['val_auc'], label='Validation AUC', color='green')
plt.title('Pretraining Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.show()

# %%
# Plot Finetuning Loss and AUC
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(finetune_data['epoch'], finetune_data['train_loss'], label='Train Loss')
plt.plot(finetune_data['epoch'], finetune_data['val_loss'], label='Validation Loss')
plt.title('Finetuning Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(finetune_data['epoch'], finetune_data['val_auc'], label='Validation AUC', color='purple')
plt.title('Finetuning Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.show()

# %%
# Summarize Evaluation Metrics
eval_summary = pd.DataFrame({
    'Dataset': ['TPDNE', '140K', 'DALL-E', 'Combined'],
    'AUC': [0.9996, 0.9950, 0.9995, 0.9958],
    'Accuracy': [0.9917, 0.9644, 0.9900, 0.9679]
})

test_summary = pd.DataFrame({
    'Dataset': ['TPDNE', '140K', 'DALL-E', 'Combined'],
    'AUC': [0.9996, 0.9950, 0.9995, 0.9958],
    'Accuracy': [0.9910, 0.9644, 0.9767, 0.9679]
})

# %%
# Visualize Evaluation Metrics
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.barplot(data=eval_summary, x='Dataset', y='AUC', ax=axes[0])
axes[0].set_title('Evaluation AUC by Dataset')
axes[0].set_ylim(0.9, 1.0)

sns.barplot(data=eval_summary, x='Dataset', y='Accuracy', ax=axes[1])
axes[1].set_title('Evaluation Accuracy by Dataset')
axes[1].set_ylim(0.9, 1.0)

plt.show()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.barplot(data=test_summary, x='Dataset', y='AUC', ax=axes[0], palette='muted')
axes[0].set_title('Testing AUC by Dataset')
axes[0].set_ylim(0.9, 1.0)

sns.barplot(data=test_summary, x='Dataset', y='Accuracy', ax=axes[1], palette='muted')
axes[1].set_title('Testing Accuracy by Dataset')
axes[1].set_ylim(0.9, 1.0)

plt.show()

print("\nProject Results Summary:")
print("- Pretraining achieved AUC up to 0.9653.")
print("- Finetuning further improved AUC up to 0.9963.")
print("- Across TPDNE, 140K, DALL-E, and Combined tests, the model demonstrated very strong generalization.")
# Out:
# C:\Users\marat\AppData\Local\Temp\ipykernel_28012\4183068783.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=test_summary, x='Dataset', y='AUC', ax=axes[0], palette='muted')
# C:\Users\marat\AppData\Local\Temp\ipykernel_28012\4183068783.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=test_summary, x='Dataset', y='Accuracy', ax=axes[1], palette='muted')
# Project Results Summary:
# - Pretraining achieved AUC up to 0.9653.
# - Finetuning further improved AUC up to 0.9963.
# - Across TPDNE, 140K, DALL-E, and Combined tests, the model demonstrated very strong generalization.
